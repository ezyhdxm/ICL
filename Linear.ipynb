# %%
import torch
from absl import app, flags, logging
from ml_collections import config_flags

import linear.lr_utils as u
from linear.train_linear import train
from linear.lr_config import get_config

logging.set_verbosity(logging.INFO)

# %load_ext autoreload
# %autoreload 2

# %%
config = get_config()
config = u.filter_config(config)

# %%
train(config)
# Out:
# INFO:absl:Train Experiment
# NAME: train_3b984fced732173e013a423b75f94a63
# CONFIG:
# device: cuda
# dtype: float32
# eval:
#   batch_size: 4096
#   data_seed: 104
#   every: 1000
#   n_samples: 16384
#   noise_seed: 106
#   task_seed: 105
# model:
#   n_dims: 8
#   n_embd: 128
#   n_head: 2
#   n_layer: 4
#   n_points: 16
#   name: transformer
#   seed: 100
# task:
#   batch_size: 256
#   data_scale: 1.0
#   data_seed: 101
#   n_dims: 8
#   n_points: 16
#   n_tasks: 32
#   name: noisy_linear_regression
#   noise_scale: 0.5
#   noise_seed: 103
#   task_scale: 1.0
#   task_seed: 102
# training:
#   lr: 0.001
#   optimizer: adam
#   schedule: triangle
#   total_steps: 20000
#   warmup_steps: 10000
# wandb:
#   project: ''
# work_dir: linear_results
# ...
# Layer (type:depth-idx)                        Input Shape               Output Shape              Param #
# ...
# TransformerLin                                [256, 16, 8]              [256, 16]                 --
# ...

# %%
2**20
# Out:
# 1048576
