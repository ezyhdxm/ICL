# %%
import torch
from absl import app, flags, logging
from ml_collections import config_flags

import linear.lr_utils as u
from linear.train_linear import train
from linear.lr_config import get_config

logging.set_verbosity(logging.INFO)

# %load_ext autoreload
# %autoreload 2

config = get_config()
config = u.filter_config(config)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
train(config)
# Out:
# INFO:absl:Train Experiment
# NAME: train_e4e6e2d7296e4a75343d41642082101c
# CONFIG:
# device: cuda
# dtype: float32
# eval:
#   batch_size: 4096
#   data_seed: 104
#   every: 1000
#   n_samples: 16384
#   noise_seed: 106
#   task_seed: 105
# model:
#   n_dims: 8
#   n_embd: 128
#   n_head: 1
#   n_layer: 2
#   n_points: 16
#   name: transformer
#   seed: 100
# task:
#   batch_size: 256
#   data_scale: 1.0
#   data_seed: 101
#   n_dims: 8
#   n_points: 16
#   n_tasks: 32
#   name: noisy_linear_regression
#   noise_scale: 0.5
#   noise_seed: 103
#   task_scale: 1.0
#   task_seed: 102
# training:
#   lr: 0.001
#   optimizer: adam
#   schedule: triangle
#   total_steps: 100000
#   warmup_steps: 50000
# wandb:
#   project: ICL
# work_dir: linear_results
# ========================================================================================================================
# Layer (type:depth-idx)                        Input Shape               Output Shape              Param #
# ========================================================================================================================
# TransformerLin                                [256, 16, 8]              [256, 16]                 --
# ├─Linear: 1-1                                 [256, 32, 9]              [256, 32, 128]            1,152
# ├─GPT2Model: 1-2                              [256, 32, 128]            [256, 32, 128]            --
# │    └─Dropout: 2-1                           [256, 32, 128]            [256, 32, 128]            --
# │    └─ModuleList: 2-2                        --                        --                        --
# │    │    └─GPT2Block: 3-1                    [256, 32, 128]            [256, 32, 128]            198,272
# │    │    └─GPT2Block: 3-2                    [256, 32, 128]            [256, 32, 128]            198,272
# │    └─LayerNorm: 2-3                         [256, 32, 128]            [256, 32, 128]            256
# ├─Linear: 1-3                                 [256, 32, 128]            [256, 32, 1]              128
# ========================================================================================================================
# Total params: 398,080
# Trainable params: 398,080
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 101.91
# ========================================================================================================================
# Input size (MB): 0.15
# Forward/backward pass size (MB): 201.39
# Params size (MB): 1.59
# Estimated Total Size (MB): 203.13
# ========================================================================================================================
# Initialized model, optimizer, and train state
# Initialized data samplers
# Evaluating baselines...
# Finishing last run (ID:0hky3kc1) before initializing another...
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/Latent/Ridge</td><td>▄▂▁▁▁▁▂▂▃▃▄▄▅▅▆▆▇▇██</td></tr><tr><td>eval/Latent/True</td><td>▄▂▁▁▁▁▂▂▃▃▄▄▅▅▆▆▇▇██</td></tr><tr><td>eval/Latent/dMMSE</td><td>█▇▇▇▇▇▆▅▄▃▃▃▂▂▂▁▁▁▁▁</td></tr><tr><td>eval/Pretrain/Ridge</td><td>█▃▂▁▁▁▁▁▂▂▃▃▃▃▄▄▆▆▆▇</td></tr><tr><td>eval/Pretrain/True</td><td>█▆▅▅▅▄▄▄▃▃▃▃▃▂▂▂▂▁▁▁</td></tr><tr><td>eval/Pretrain/dMMSE</td><td>█▆▅▅▅▄▄▄▃▃▃▃▃▂▂▂▂▁▁▁</td></tr><tr><td>train/lr</td><td>▂▂▃▄▅▅▆▇▇█▇▇▆▅▅▄▃▂▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/Latent/Ridge</td><td>0.44073</td></tr><tr><td>eval/Latent/True</td><td>0.78793</td></tr><tr><td>eval/Latent/dMMSE</td><td>0.33079</td></tr><tr><td>eval/Pretrain/Ridge</td><td>0.18072</td></tr><tr><td>eval/Pretrain/True</td><td>0.15161</td></tr><tr><td>eval/Pretrain/dMMSE</td><td>0.02274</td></tr><tr><td>train/lr</td><td>0</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">train_2774f53cf8eaaa1871485167bc017bfa</strong> at: <a href='https://wandb.ai/hyan84-university-of-wisconsin-madison/ICL/runs/0hky3kc1' target="_blank">https://wandb.ai/hyan84-university-of-wisconsin-madison/ICL/runs/0hky3kc1</a><br/> View project at: <a href='https://wandb.ai/hyan84-university-of-wisconsin-madison/ICL' target="_blank">https://wandb.ai/hyan84-university-of-wisconsin-madison/ICL</a><br/>Synced 4 W&B file(s), 0 media file(s), 3 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250401_014438-0hky3kc1\logs</code>
# Successfully finished last run (ID:0hky3kc1). Initializing new run:<br/>
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>C:\Users\Hao\Downloads\LLM\ICL\wandb\run-20250401_015341-xwxf8jzp</code>
# Syncing run <strong><a href='https://wandb.ai/hyan84-university-of-wisconsin-madison/ICL/runs/xwxf8jzp' target="_blank">train_e4e6e2d7296e4a75343d41642082101c</a></strong> to <a href='https://wandb.ai/hyan84-university-of-wisconsin-madison/ICL' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hyan84-university-of-wisconsin-madison/ICL' target="_blank">https://wandb.ai/hyan84-university-of-wisconsin-madison/ICL</a>
#  View run at <a href='https://wandb.ai/hyan84-university-of-wisconsin-madison/ICL/runs/xwxf8jzp' target="_blank">https://wandb.ai/hyan84-university-of-wisconsin-madison/ICL/runs/xwxf8jzp</a>
# Start training...
# Step: 1000
# Step: 2000
# Step: 3000
# Step: 4000
# Step: 5000
# Step: 6000
# Step: 7000
# Step: 8000
# Step: 9000
# Step: 10000
# Step: 11000
# Step: 12000
# Step: 13000
# Step: 14000
# Step: 15000
# Step: 16000
# Step: 17000
# Step: 18000
# Step: 19000
# Step: 20000
# Step: 21000
# Step: 22000
# Step: 23000
# Step: 24000
# Step: 25000
# Step: 26000
# Step: 27000
# Step: 28000
# Step: 29000
# Step: 30000
# Step: 31000
# Step: 32000
# Step: 33000
# Step: 34000
# Step: 35000
# Step: 36000
# Step: 37000
# Step: 38000
# Step: 39000
# Step: 40000
# Step: 41000
# Step: 42000
# Step: 43000
# Step: 44000
# Step: 45000
# Step: 46000
# Step: 47000
# Step: 48000
# Step: 49000
# Step: 50000
# Step: 51000
# Step: 52000
# Step: 53000
# Step: 54000
# Step: 55000
# Step: 56000
# Step: 57000
# Step: 58000
# Step: 59000
# Step: 60000
# Step: 61000
# Step: 62000
# Step: 63000
# Step: 64000
# Step: 65000
# Step: 66000
# Step: 67000
# Step: 68000
# Step: 69000
# Step: 70000
# Step: 71000
# Step: 72000
# Step: 73000
# Step: 74000
# Step: 75000
# Step: 76000
# Step: 77000
# Step: 78000
# Step: 79000
# Step: 80000
# Step: 81000
# Step: 82000
# Step: 83000
# Step: 84000
# Step: 85000
# Step: 86000
# Step: 87000
# Step: 88000
# Step: 89000
# Step: 90000
# Step: 91000
# Step: 92000
# Step: 93000
# Step: 94000
# Step: 95000
# Step: 96000
# Step: 97000
# Step: 98000
# Step: 99000
# Step: 100000
# Training complete.
